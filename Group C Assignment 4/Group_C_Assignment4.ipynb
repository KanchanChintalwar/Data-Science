# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('covid_vaccine_statewise.csv')

# %%
df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
df.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
df.shape
# Out:
# (7845, 24)

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
min_count =  int(((100-40)/100)*df.shape[1] + 1)
df = df.dropna( axis=0, thresh=min_count)

# %%
df.head()
# Out:
#     Updated On  State  Total Doses Administered   Sessions   Sites   \
# 59  16/03/2021  India                31870745.0  5366679.0  33886.0
# 60  17/03/2021  India                36496020.0  5183313.0  31807.0
# 61  18/03/2021  India                38770404.0  5880856.0  38208.0
# 62  19/03/2021  India                41309219.0  6385874.0  41625.0
# 63  20/03/2021  India                43877868.0  6470646.0  42178.0
#
#     First Dose Administered  Second Dose Administered  \
# 59               25709257.0                 6161488.0
# 60               30011328.0                 6484692.0
# 61               31952935.0                 6817469.0
# 62               34228371.0                 7080848.0
# 63               36568988.0                 7308880.0
#
#     Male (Doses Administered)  Female (Doses Administered)  \
# 59                        NaN                          NaN
# 60                        NaN                          NaN
# ...

# %%
df.shape
# Out:
# (5436, 24)

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                  0
# Sessions                                  0
#  Sites                                    0
# First Dose Administered                   0
# Second Dose Administered                  0
# Male (Doses Administered)               101
# Female (Doses Administered)             101
# Transgender (Doses Administered)        101
#  Covaxin (Doses Administered)             0
# CoviShield (Doses Administered)           0
# Sputnik V (Doses Administered)         2441
# AEFI                                      0
# 18-44 Years (Doses Administered)       3734
# 45-60 Years (Doses Administered)       3734
# 60+ Years (Doses Administered)         3734
# 18-44 Years(Individuals Vaccinated)    1703
# 45-60 Years(Individuals Vaccinated)    1702
# 60+ Years(Individuals Vaccinated)      1702
# Male(Individuals Vaccinated)           5335
# ...

# %%
df = df.drop(['Male(Individuals Vaccinated)', 'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)'],axis = 1)

# %%
df.shape
# Out:
# (5436, 21)

# %%
group = df.groupby("State")

# %%
group['First Dose Administered'].agg([np.sum])
# Out:
#                                                    sum
# State
# Andaman and Nicobar Islands               1.618536e+07
# Andhra Pradesh                            1.213091e+09
# Arunachal Pradesh                         4.802236e+07
# Assam                                     5.769440e+08
# Bihar                                     1.447376e+09
# Chandigarh                                4.403833e+07
# Chhattisgarh                              7.811960e+08
# Dadra and Nagar Haveli and Daman and Diu  3.309826e+07
# Delhi                                     6.120877e+08
# Goa                                       7.506311e+07
# Gujarat                                   2.091952e+09
# Haryana                                   7.463051e+08
# Himachal Pradesh                          3.124296e+08
# India                                     2.779994e+10
# Jammu and Kashmir                         4.022143e+08
# Jharkhand                                 5.931097e+08
# ...

# %%
group['Second Dose Administered'].agg([np.sum])
# Out:
#                                                    sum
# State
# Andaman and Nicobar Islands               4.067337e+06
# Andhra Pradesh                            3.546311e+08
# Arunachal Pradesh                         1.171354e+07
# Assam                                     1.296856e+08
# Bihar                                     2.670690e+08
# Chandigarh                                1.152356e+07
# Chhattisgarh                              1.697363e+08
# Dadra and Nagar Haveli and Daman and Diu  4.506390e+06
# Delhi                                     1.866747e+08
# Goa                                       1.606005e+07
# Gujarat                                   5.938450e+08
# Haryana                                   1.569462e+08
# Himachal Pradesh                          7.296004e+07
# India                                     6.680902e+09
# Jammu and Kashmir                         8.533163e+07
# Jharkhand                                 1.206596e+08
# ...
