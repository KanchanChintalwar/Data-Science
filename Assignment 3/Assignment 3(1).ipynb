# %%
import pandas as pd
import numpy as np            # Importing the libraries

# %%
df = pd.read_csv("nba.csv")               # Reading the csv file

# %%
df.head()             # displaying top 5 rows
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.describe()           # descibing the dataset
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.shape
# Out:
# (458, 9)

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
print(df[df.Name.isnull()])
df.Name.dropna(inplace = True)
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %%
df = df.iloc[:457]
df.shape
# Out:
# (457, 9)

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.groupby("College")

# %%
df.College.nunique()
# Out:
# 118

# %%
df.College.unique()
# Out:
# array(['Texas', 'Marquette', 'Boston University', 'Georgia State', nan,
#        'LSU', 'Gonzaga', 'Louisville', 'Oklahoma State', 'Ohio State',
#        'Washington', 'Kentucky', 'North Carolina', 'Arizona',
#        'Georgia Tech', 'Cincinnati', 'Miami (FL)', 'Stanford', 'Syracuse',
#        'Saint Louis', 'Kansas', 'Georgetown', 'Texas A&M', 'UCLA', 'UNLV',
#        'Wichita State', "Saint Joseph's", 'Notre Dame', 'Norfolk State',
#        'Duke', 'Murray State', 'Tennessee State', 'Bowling Green',
#        'Purdue', 'Wake Forest', 'Michigan', 'Missouri', 'USC',
#        'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson', 'Vanderbilt',
#        'Michigan State', 'Florida', 'Washington State', 'Arizona State',
#        'Oklahoma', 'Wyoming', "St. John's", 'Maryland', 'Wisconsin',
#        'Utah Valley', 'North Carolina State', 'UC Santa Barbara',
#        'Baylor', 'Connecticut', 'Oregon State', 'New Mexico', 'Oregon',
# ...

# %%
df.College.fillna("Not mentioned", inplace = True)

# %%
df.Salary.fillna(df.Salary.median(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df.groupby("Team").Number.describe().transpose()        # grouping the dataset by Team and descibing the Number column
# Out:
# Team   Atlanta Hawks  Boston Celtics  Brooklyn Nets  Charlotte Hornets  \
# count      15.000000       15.000000      15.000000          15.000000
# mean       19.000000       31.866667      18.266667          17.133333
# std        11.476684       30.300558      14.104035          16.672761
# min         0.000000        0.000000       0.000000           0.000000
# 25%        11.500000        9.500000       8.000000           4.000000
# 50%        17.000000       28.000000      15.000000          12.000000
# 75%        25.500000       42.500000      27.000000          27.500000
# max        43.000000       99.000000      44.000000          50.000000
#
# Team   Chicago Bulls  Cleveland Cavaliers  Dallas Mavericks  Denver Nuggets  \
# count      15.000000            15.000000         15.000000       15.000000
# mean       19.200000            14.466667         20.000000       15.266667
# std        17.193022            13.809245         16.252472       19.655849
# ...

# %%
df.groupby("Team").Age.describe().transpose()        # grouping the dataset by Team and descibing the Age column
# Out:
# Team   Atlanta Hawks  Boston Celtics  Brooklyn Nets  Charlotte Hornets  \
# count      15.000000       15.000000      15.000000          15.000000
# mean       28.200000       24.733333      25.600000          26.133333
# std         4.229151        2.840188       3.018988           3.159265
# min        22.000000       20.000000      21.000000          21.000000
# 25%        24.000000       22.000000      23.500000          23.500000
# 50%        27.000000       25.000000      26.000000          27.000000
# 75%        31.000000       27.000000      27.500000          28.500000
# max        35.000000       29.000000      32.000000          31.000000
#
# Team   Chicago Bulls  Cleveland Cavaliers  Dallas Mavericks  Denver Nuggets  \
# count      15.000000            15.000000         15.000000       15.000000
# mean       27.400000            29.533333         29.733333       25.733333
# std         4.188419             4.120795          3.712271        4.742915
# ...

# %%
df.groupby("Team").Height.describe().transpose()        # grouping the dataset by Team and descibing the Height column
# Out:
# Team   Atlanta Hawks Boston Celtics Brooklyn Nets Charlotte Hornets  \
# count             15             15            15                15
# unique            11             10             8                11
# top              6-5            6-2           6-3               6-3
# freq               2              2             3                 2
#
# Team   Chicago Bulls Cleveland Cavaliers Dallas Mavericks Denver Nuggets  \
# count             15                  15               15             15
# unique            10                  11               10             10
# top              6-9                6-11             6-11            6-8
# freq               3                   2                3              3
#
# Team   Detroit Pistons Golden State Warriors  ... Oklahoma City Thunder  \
# count               15                    15  ...                    15
# unique               9                     8  ...                     9
# ...

# %%
df.groupby("Team").Weight.describe().transpose()       # grouping the dataset by Team and descibing the Weight column
# Out:
# Team   Atlanta Hawks  Boston Celtics  Brooklyn Nets  Charlotte Hornets  \
# count      15.000000       15.000000       15.00000          15.000000
# mean      221.266667      219.466667      215.60000         220.400000
# std        25.982045       25.606547       24.37739          29.908909
# min       172.000000      180.000000      175.00000         184.000000
# 25%       203.000000      197.500000      200.00000         200.000000
# 50%       225.000000      220.000000      216.00000         210.000000
# 75%       242.500000      236.500000      220.50000         240.000000
# max       260.000000      260.000000      275.00000         289.000000
#
# Team   Chicago Bulls  Cleveland Cavaliers  Dallas Mavericks  Denver Nuggets  \
# count      15.000000            15.000000         15.000000       15.000000
# mean      218.933333           227.866667        227.000000      217.533333
# std        29.336634            27.655706         27.836256       26.297384
# ...

# %%
df.groupby("Team").College.describe().transpose()            # grouping the dataset by Team and descibing the College column
# Out:
# Team    Atlanta Hawks Boston Celtics  Brooklyn Nets Charlotte Hornets  \
# count              15             15             15                15
# unique             12             13             13                11
# top     Not mentioned  Not mentioned  Not mentioned     Not mentioned
# freq                4              2              2                 2
#
# Team    Chicago Bulls Cleveland Cavaliers Dallas Mavericks Denver Nuggets  \
# count              15                  15               15             15
# unique             12                  11               12             10
# top     Not mentioned       Not mentioned    Not mentioned  Not mentioned
# freq                3                   3                3              6
#
# Team   Detroit Pistons Golden State Warriors  ... Oklahoma City Thunder  \
# count               15                    15  ...                    15
# unique              15                    12  ...                    14
# ...

# %%
df.groupby("Team").Position.describe().transpose()           # grouping the dataset by Team and descibing the Position column
# Out:
# Team   Atlanta Hawks Boston Celtics Brooklyn Nets Charlotte Hornets  \
# count             15             15            15                15
# unique             5              5             4                 5
# top               SG             PG            SG                SG
# freq               4              4             6                 5
#
# Team   Chicago Bulls Cleveland Cavaliers Dallas Mavericks Denver Nuggets  \
# count             15                  15               15             15
# unique             5                   5                5              5
# top               PF                  SG               PG             SG
# freq               5                   5                4              4
#
# Team   Detroit Pistons Golden State Warriors  ... Oklahoma City Thunder  \
# count               15                    15  ...                    15
# unique               5                     5  ...                     5
# ...

# %%
df.groupby("Team").Salary.describe().transpose()       # grouping the dataset by Team and descibing the Salary column
# Out:
# Team   Atlanta Hawks  Boston Celtics  Brooklyn Nets  Charlotte Hornets  \
# count   1.500000e+01    1.500000e+01   1.500000e+01       1.500000e+01
# mean    4.860197e+06    4.092009e+06   3.501898e+06       5.222728e+06
# std     5.194508e+06    3.051344e+06   5.317817e+06       4.538601e+06
# min     5.250930e+05    1.148640e+06   1.342150e+05       1.894550e+05
# 25%     1.152260e+06    1.994760e+06   9.472760e+05       1.543138e+06
# 50%     2.854940e+06    2.839073e+06   1.335480e+06       4.204200e+06
# 75%     6.873240e+06    5.898058e+06   2.512675e+06       6.665702e+06
# max     1.867166e+07    1.200000e+07   1.968900e+07       1.350000e+07
#
# Team   Chicago Bulls  Cleveland Cavaliers  Dallas Mavericks  Denver Nuggets  \
# count   1.500000e+01         1.500000e+01      1.500000e+01    1.500000e+01
# mean    5.785559e+06         7.321851e+06      4.746582e+06    4.197400e+06
# std     6.251088e+06         7.551653e+06      5.030279e+06    4.179987e+06
# ...

# %%
list_of_Salary_by_Team = list(df.groupby("Team")['Salary'])
print(list_of_Salary_by_Team)                    # Finding the list of salary group by team
# Out:
# [('Atlanta Hawks', 309     2000000.0
# 310     1304520.0
# 311     2854940.0
# 312    12000000.0
# 313     1000000.0
# 314     5746479.0
# 315    18671659.0
# 316      947276.0
# 317      525093.0
# 318     1763400.0
# 319     3333333.0
# 320     4000000.0
# 321     9756250.0
# 322     1000000.0
# 323     8000000.0
# Name: Salary, dtype: float64), ('Boston Celtics', 0      7730337.0
# 1      6796117.0
# 2      2839073.0
# 3      1148640.0
# 4      5000000.0
# 5     12000000.0
# 6      1170960.0
# 7      2165160.0
# 8      1824360.0
# 9      3431040.0
# 10     2569260.0
# 11     6912869.0
# 12     3425510.0
# 13     1749840.0
# 14     2616975.0
# Name: Salary, dtype: float64), ('Brooklyn Nets', 15     3425510.0
# 16      845059.0
# 17     1500000.0
# 18     1335480.0
# 19     6300000.0
# 20     1599840.0
# 21      134215.0
# 22     1500000.0
# 23    19689000.0
# 24     1140240.0
# 25      947276.0
# 26      981348.0
# 27      947276.0
# 28      947276.0
# 29    11235955.0
# ...

# %%
bins = [19, 25, 30, 35, 40]
labels = ['19-24', '25-28', '29-35', '36-40']
df['Agegroup'] = pd.cut(df['Age'], bins = bins, labels=labels, right = False)    # Dividing the age into groups and making a new column named Age group

# %%
df.Agegroup.value_counts()     # Calculating the number of values in Age group
# Out:
# 25-28    181
# 19-24    154
# 29-35     90
# 36-40     29
# Name: Agegroup, dtype: int64

# %%
df.groupby('Agegroup').Salary.mean()      # grouping the dataset by Agegroup and finding the mean of Salary column
# Out:
# Agegroup
# 19-24    2.709663e+06
# 25-28    5.635022e+06
# 29-35    7.037296e+06
# 36-40    3.671810e+06
# Name: Salary, dtype: float64

# %%
df.groupby('Agegroup').Salary.median()    # grouping the dataset by Agegroup and finding the median of Salary column
# Out:
# Agegroup
# 19-24    1721379.5
# 25-28    3425510.0
# 29-35    5209584.5
# 36-40    2839073.0
# Name: Salary, dtype: float64

# %%
df.groupby('Agegroup').Salary.describe()     # grouping the dataset by Agegroup and describing the Salary column
# Out:
#           count          mean           std       min        25%        50%  \
# Agegroup
# 19-24     154.0  2.709663e+06  3.146584e+06   30888.0  1000000.0  1721379.5
# 25-28     181.0  5.635022e+06  5.501674e+06   55722.0  1035000.0  3425510.0
# 29-35      90.0  7.037296e+06  6.124321e+06  200600.0  2312500.0  5209584.5
# 36-40      29.0  3.671810e+06  4.587180e+06  222888.0   947276.0  2839073.0
#
#                  75%         max
# Agegroup
# 19-24      3065499.0  16407501.0
# 25-28      8988765.0  20158622.0
# 29-35     10052771.5  22970500.0
# 36-40      4088019.0  25000000.0

# %%
# List_of_Categories_in_Agegroup = list(df['Agegroup'].value_counts().index)

# %%
# print(List_of_Categories_in_Agegroup)

# %%
list_of_salaries_by_Agegroup = list(df.groupby('Agegroup')['Salary'])        # Finding the list of salary group by age group

# %%
print(list_of_salaries_by_Agegroup)
# Out:
# [('19-24', 3       1148640.0
# 6       1170960.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
#           ...
# 446    12000000.0
# 447     1175880.0
# 449     1348440.0
# 452     2239800.0
# 454      900000.0
# Name: Salary, Length: 154, dtype: float64), ('25-28', 0       7730337.0
# 1       6796117.0
# 2       2839073.0
# 4       5000000.0
# 5      12000000.0
#           ...
# 450     2050000.0
# 451      981348.0
# 453     2433333.0
# 455     2900000.0
# 456      947276.0
# Name: Salary, Length: 181, dtype: float64), ('29-35', 19      6300000.0
# 30      8000000.0
# 31      1635476.0
# 33     22875000.0
# 34      7402812.0
#           ...
# 405    12100000.0
# 415     3135000.0
# 421     3344000.0
# 434     5016000.0
# 440     2854940.0
# Name: Salary, Length: 90, dtype: float64), ('36-40', 46      2839073.0
# 72      2900000.0
# 93      5675000.0
# 101     3376000.0
# 102      947726.0
# 109    25000000.0
# 119      947276.0
# 139     1449187.0
# 154     4500000.0
# ...

# %%
df.groupby('Position')['Salary'].describe().T       # grouping the dataset by position and describing the salary column
# Out:
# Position             C            PF            PG            SF            SG
# count     7.800000e+01  1.000000e+02  9.200000e+01  8.500000e+01  1.020000e+02
# mean      5.967052e+06  4.510781e+06  4.980492e+06  4.833648e+06  3.975426e+06
# std       5.787989e+06  4.735992e+06  4.960818e+06  5.980005e+06  4.428862e+06
# min       8.339700e+04  1.114440e+05  5.572200e+04  3.088800e+04  5.572200e+04
# 25%       1.328880e+06  1.123722e+06  1.448610e+06  1.000000e+06  9.472760e+05
# 50%       3.811060e+06  2.877470e+06  2.927470e+06  2.041080e+06  2.394102e+06
# 75%       9.620558e+06  5.543725e+06  7.000000e+06  5.500000e+06  5.675000e+06
# max       2.235936e+07  2.219273e+07  2.146870e+07  2.500000e+07  2.000000e+07

# %%
list_of_Salary_by_Position = list(df.groupby('Position')['Salary'])
print(list_of_Salary_by_Position)       # Finding the list of salary group by position
# Out:
# [('C', 7       2165160.0
# 10      2569260.0
# 14      2616975.0
# 23     19689000.0
# 27       947276.0
#           ...
# 434     5016000.0
# 439     1415520.0
# 447     1175880.0
# 455     2900000.0
# 456      947276.0
# Name: Salary, Length: 78, dtype: float64), ('PF', 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 24      1140240.0
# 25       947276.0
#           ...
# 435     3075880.0
# 441     2637720.0
# 442     4775000.0
# 446    12000000.0
# 452     2239800.0
# Name: Salary, Length: 100, dtype: float64), ('PG', 0      7730337.0
# 8      1824360.0
# 9      3431040.0
# 11     6912869.0
# 19     6300000.0
#          ...
# 440    2854940.0
# 443    2658240.0
# 445    3777720.0
# 453    2433333.0
# 454     900000.0
# Name: Salary, Length: 92, dtype: float64), ('SF', 1       6796117.0
# 32        30888.0
# 33     22875000.0
# 35       845059.0
# 42      1636842.0
#           ...
# 428     8042895.0
# 432     2894059.0
# 448    15409570.0
# 450     2050000.0
# ...

# %%
df1 = pd.read_csv("Iris.csv")
df1.head()                             # Reading the Iris.csv file in df1
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1.shape
# Out:
# (150, 6)

# %%
df1.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df1.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df1.groupby('Species')['SepalLengthCm'].describe()    # grouping the dataset by species and describing the SepalLengthCm column
# Out:
#                  count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
df1.groupby('Species')['SepalWidthCm'].describe()    # grouping the dataset by species and describing the SepalWidthCm column
# Out:
#                  count   mean       std  min    25%  50%    75%  max
# Species
# Iris-setosa       50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
df1.groupby('Species')['PetalLengthCm'].describe()     # grouping the dataset by species and describing the PetalLengthCm column
# Out:
#                  count   mean       std  min  25%   50%    75%  max
# Species
# Iris-setosa       50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# Iris-versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Iris-virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
df1.groupby('Species')['PetalWidthCm'].describe()     # grouping the dataset by species and describing the PetalWidthCm column
# Out:
#                  count   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa       50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor   50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica    50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5
